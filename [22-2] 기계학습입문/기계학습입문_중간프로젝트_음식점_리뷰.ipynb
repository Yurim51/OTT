# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #1. 데이터 확인

# %% [markdown]
# 데이터 출처: https://www.kaggle.com/datasets/ninetyninenewton/kr3-korean-restaurant-reviews-with-ratings

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Data/음식점리뷰.tsv', sep='\t') 
df1
# Out:
#        Region  Rating    Category  \
# 0         인덕원       1     삼겹살 고기집
# 1         인덕원       1     삼겹살 고기집
# 2         인덕원       1    순대국 찹쌀순대
# 3         인덕원       1    순대국 찹쌀순대
# 4         인덕원       1    순대국 찹쌀순대
# ...       ...     ...         ...
# 642408     평택       2  일식/중식/세계음식
# 642409     평택       0          한식
# 642410     평택       1          한식
# 642411     평택       2      카페/디저트
# 642412     평택       2          한식
#
#                                                    Review
# 0       숙성 돼지고기 전문점입니다. 건물 모양 때문에 매장 모양도 좀 특이하지만 쾌적한 편...
# 1       고기가 정말 맛있었어요! 육즙이 가득있어서 너무 좋았아요\n일하시는분들 너무 친절하...
# 2       잡내없고 깔끔, 담백한 맛의 순대국이 순대국을 안 좋아하는 사람들에게도 술술 넘어갈...
# 3       고기 양이 푸짐해서 특 순대국밥을 시킨 기분이 듭니다~~ 맛도 좋습니다\n다만 양념...
# 4       순대국 자체는 제가 먹어본 순대국밥집 중에서 Top5 안에는 들어요.\n\n그러나 ...
# ...                                                   ...
# 642408  요즘, 핫하게,,,떠오르구 있는 중국집. ㅋ, 맥주의 여파루 속이 안좋지만 와봄. ...
# 642409  원래 글 안쓰는데 이거는 정말 다른분들 위해서 써야할것같네요 방금 포장주문 해서 왔...
# ...

# %% [markdown]
#  - 0: 부정
#  - 1: 긍정
#  - 2: 모호

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 642413 entries, 0 to 642412
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Region    642413 non-null  object
#  1   Rating    642413 non-null  int64
#  2   Category  642389 non-null  object
#  3   Review    642413 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 19.6+ MB

# %%
sns.countplot(x='Rating', data=df1)

# %%
df_review = df1[(df1['Rating'] == 0) | (df1['Rating'] == 1)]
df_review
# Out:
#        Region  Rating    Category  \
# 0         인덕원       1     삼겹살 고기집
# 1         인덕원       1     삼겹살 고기집
# 2         인덕원       1    순대국 찹쌀순대
# 3         인덕원       1    순대국 찹쌀순대
# 4         인덕원       1    순대국 찹쌀순대
# ...       ...     ...         ...
# 642404     평택       0  일식/중식/세계음식
# 642405     평택       1          한식
# 642406     평택       1          한식
# 642409     평택       0          한식
# 642410     평택       1          한식
#
#                                                    Review
# 0       숙성 돼지고기 전문점입니다. 건물 모양 때문에 매장 모양도 좀 특이하지만 쾌적한 편...
# 1       고기가 정말 맛있었어요! 육즙이 가득있어서 너무 좋았아요\n일하시는분들 너무 친절하...
# 2       잡내없고 깔끔, 담백한 맛의 순대국이 순대국을 안 좋아하는 사람들에게도 술술 넘어갈...
# 3       고기 양이 푸짐해서 특 순대국밥을 시킨 기분이 듭니다~~ 맛도 좋습니다\n다만 양념...
# 4       순대국 자체는 제가 먹어본 순대국밥집 중에서 Top5 안에는 들어요.\n\n그러나 ...
# ...                                                   ...
# 642404  7/31 배달 시켜 먹었구요, 거리상 1.8km 입니다. 배민에서 시켰고 정확히 5...
# 642405  송탄 미군부대 근처에 위치한 곳 원래 로컬맛집으로 되게 유명했는데 삼대천왕에 나온 ...
# ...

# %%
sns.countplot(x='Rating', data=df_review)
print("긍정 개수:", (df_review["Rating"] == 1).sum())
print("부정 개수:", (df_review["Rating"] == 0).sum())
# Out:
# 긍정 개수: 388567
# 부정 개수: 70980

# %%
pos = df_review[df_review["Rating"] == 1]
neg = df_review[df_review["Rating"] == 0]
pos
# Out:
#        Region  Rating  Category  \
# 0         인덕원       1   삼겹살 고기집
# 1         인덕원       1   삼겹살 고기집
# 2         인덕원       1  순대국 찹쌀순대
# 3         인덕원       1  순대국 찹쌀순대
# 4         인덕원       1  순대국 찹쌀순대
# ...       ...     ...       ...
# 642392     평택       1        한식
# 642401     평택       1        한식
# 642405     평택       1        한식
# 642406     평택       1        한식
# 642410     평택       1        한식
#
#                                                    Review
# 0       숙성 돼지고기 전문점입니다. 건물 모양 때문에 매장 모양도 좀 특이하지만 쾌적한 편...
# 1       고기가 정말 맛있었어요! 육즙이 가득있어서 너무 좋았아요\n일하시는분들 너무 친절하...
# 2       잡내없고 깔끔, 담백한 맛의 순대국이 순대국을 안 좋아하는 사람들에게도 술술 넘어갈...
# 3       고기 양이 푸짐해서 특 순대국밥을 시킨 기분이 듭니다~~ 맛도 좋습니다\n다만 양념...
# 4       순대국 자체는 제가 먹어본 순대국밥집 중에서 Top5 안에는 들어요.\n\n그러나 ...
# ...                                                   ...
# 642392  가격대비 괜찮긴한데 가격을 자꾸 올리고 샐러드바 메뉴는 줄어드는 경향이 있어서 살짝...
# 642401  리뷰에직원이 친절하지않다더니 정말이네요 선불이라 만원짜리내고 기다리고있는데 거지동냥...
# ...

# %%
pos_revised = pos.sample(n=neg.shape[0], random_state=45)
pos_revised
# Out:
#        Region  Rating       Category  \
# 574580    서초구       1         카페/디저트
# 636752     중구       1             한식
# 496208    강남구       1             일식
# 6745      인덕원       1       한정식 황태구이
# 293610    용산구       1          기타 양식
# ...       ...     ...            ...
# 205592   영등포구       1          족발,보쌈
# 376632    강남구       1  정통 중식 / 일반 중식
# 300309    용산구       1           이탈리안
# 58917     인덕원       1      베이커리 휘낭시에
# 308468    광진구       1          기타 중식
#
#                                                    Review
# 574580                                         빵맛이 아주 좋아요
# 636752                            개인적으로 진짜오랜만에 맘에드는식당이였네요
# 496208  평일 오후 1시라 그런건지 모르겠는데, 이 바로 전타임이 빠지고 혼자서 아주 좋게 ...
# 6745    ※ 가성비 좋은 메뉴를 갖춘 한정식집입니다.\n\n소리마을은 한정식 체인으로 퇴촌면...
# 293610  가~장 좋아하는 피자집..\n정석으로 시켜먹어야 한당!!ㅠㅠ 치즈 풍미도 대박이고 ...
# ...                                                   ...
# 205592     기본으로 주는 청국장도 굿?, 보쌈도 먹기좋은 적당한 기름끼, 얇은 두께 좋아요~~
# ...

# %%
total = pd.concat([pos_revised, neg], ignore_index=True)
total
# Out:
#        Region  Rating    Category  \
# 0         서초구       1      카페/디저트
# 1          중구       1          한식
# 2         강남구       1          일식
# 3         인덕원       1    한정식 황태구이
# 4         용산구       1       기타 양식
# ...       ...     ...         ...
# 141955     평택       0  일식/중식/세계음식
# 141956     평택       0          한식
# 141957     평택       0  일식/중식/세계음식
# 141958     평택       0  일식/중식/세계음식
# 141959     평택       0          한식
#
#                                                    Review
# 0                                              빵맛이 아주 좋아요
# 1                                 개인적으로 진짜오랜만에 맘에드는식당이였네요
# 2       평일 오후 1시라 그런건지 모르겠는데, 이 바로 전타임이 빠지고 혼자서 아주 좋게 ...
# 3       ※ 가성비 좋은 메뉴를 갖춘 한정식집입니다.\n\n소리마을은 한정식 체인으로 퇴촌면...
# 4       가~장 좋아하는 피자집..\n정석으로 시켜먹어야 한당!!ㅠㅠ 치즈 풍미도 대박이고 ...
# ...                                                   ...
# 141955  평일런치라 그런지 메뉴가 진짜 없네요ㅠ 소고기 양도 적구..... 흑임자아이스크림과...
# 141956  맛은 미원탕..... 컨셉이 없는 불친절함(우리한테만 그러나하구 여러팀 봤는데 불친...
# ...

# %%
import sklearn
df = sklearn.utils.shuffle(total, random_state=45).reset_index(drop=True)
df
# Out:
#        Region  Rating          Category  \
# 0          수원       0                국수
# 1          제주       1             육류,고기
# 2         종로구       1          카페 / 디저트
# 3          중구       1                뷔페
# 4         강남구       0                분식
# ...       ...     ...               ...
# 141955    서초구       1             퓨전 일식
# 141956     세종       0             커피전문점
# 141957     진주       1            고기/구이류
# 141958    군산시       0            해산물 요리
# 141959    경주시       0  한정식 / 백반 / 정통 한식
#
#                                                    Review
# 0          원래 리뷰 잘 안남기는데 돈은 똑같이 처받고 여자남자 양 다르게 주는게 빡쳐서 남김
# 1                                  완전 맛있어 고기 또 구워주고 시네 최고
# 2       "이런데 누가 가?" 했는데 내가 감\n대박 맛있음\n팥죽 정말 싫어하는데 너무 맛...
# 3       영종도의 핫한 네스트호텔 내에 있는 플라츠 레스토랑.\n삼면이 통유리로 되어있어 파...
# 4                                       별한개도 아깝다. 줘도 안먹는다
# ...                                                   ...
# 141955  명란리조또가 정말 맛났다♥ 파스타보단 갠적으로 리조또종류들이 더맛있었다. 리조또 계...
# ...

# %%
sns.countplot(x='Rating', data=df)
print("긍정 개수:", (df["Rating"] == 1).sum())
print("부정 개수:", (df["Rating"] == 0).sum())
# Out:
# 긍정 개수: 70980
# 부정 개수: 70980

# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ## 정규 표현식

# %%
# 정규 표현식 함수 정의

import re

def apply_regular_expression(text):
    hangul = re.compile('[^ ㄱ-ㅣ 가-힣]')
    result = hangul.sub('', text)
    return result

# %%
df['Review'][:20]
# Out:
# 0        원래 리뷰 잘 안남기는데 돈은 똑같이 처받고 여자남자 양 다르게 주는게 빡쳐서 남김
# 1                                완전 맛있어 고기 또 구워주고 시네 최고
# 2     "이런데 누가 가?" 했는데 내가 감\n대박 맛있음\n팥죽 정말 싫어하는데 너무 맛...
# 3     영종도의 핫한 네스트호텔 내에 있는 플라츠 레스토랑.\n삼면이 통유리로 되어있어 파...
# 4                                     별한개도 아깝다. 줘도 안먹는다
# 5     순대국 안좋아했는데 농민백암순대 먹고선 좋아하게 됨.... 깍두기며 된장까지 맛있음...
# 6     그냥 빕스.. 무난할때 가지만 역시 고기도 그렇게 좋은 질은 아니다 가끔 스테이크가...
# 7                                               개판. 맛없음
# 8                                    절대 가지마세요 개노맛 진심입니다
# 9     진짜 손님 줄 관리를 못하네요 30분 넘게 기다렸는데 직원(?)이 이름 적었냐고 물...
# 10    맛은 평범합니다 9000원  최악 중에 최악   일단 가격이 조금 띠용한데 요즘 물...
# 11    일단 분위기는 좋다. 토속적이고 정갈한 분위기.\n음식은 전체적으로 간이 약하고 건...
# 12    연남동에서 모임장소를 고민하던 찰나에 포잉 평점이 꽤 높은 편이라 믿고 예약해서 다...
# 13    음식이 전체적으로 맛있음\n특히 김치찜 메뉴가 만족스러우며 콩나물국밥은 기본이상\n...
# 14    도도한 고양이씨가 반겨주시는 서촌의 냉면집입니다. 왕만두국이 뜨끈하니 참 맛있어요....
# 15    백반이 먹고싶어서 갔는데 반찬이 별로 맛이 특별한게 없고 그냥 그렇습니다.\n\n그...
# 16    곱창이 듬뿍 들어간 닭볶음탕전문점. 이 근처에서는 맛집인 것 같다. 가게 입구에 웨...
# ...

# %%
# 정규 표현식 사용 예1
print(df['Review'][2])
print('*'*20)
print(apply_regular_expression(df['Review'][2]))
# Out:
# "이런데 누가 가?" 했는데 내가 감
# 대박 맛있음
# 팥죽 정말 싫어하는데 너무 맛있어서 눈물이ㅠ
# 한방 향와 팥항이 오묘한 조화를 이룸
#
# 고명으로 나오는 견과류도 너무 잘어울림
#
# 몇년전부터 삼청동에서 안망하고
# 자리 지키고 있는게 너무 신기했음
#
# 팥죽을 싫어하는 나한테 팥죽을 전문으로 파는데가
# 있다는것 자체만으로도 문화컬쳐
#
# 역시 경험해보기 전에 함부로 판단하면 안된다고 느낌
#
# 너무너무 맛있음ㅠㅠㅠ!!!
#
# 여지껏 삼청동에서 먹은 음식중 가장 맛있었다.
# ********************
# 이런데 누가 가 했는데 내가 감대박 맛있음팥죽 정말 싫어하는데 너무 맛있어서 눈물이ㅠ한방 향와 팥항이 오묘한 조화를 이룸고명으로 나오는 견과류도 너무 잘어울림몇년전부터 삼청동에서 안망하고자리 지키고 있는게 너무 신기했음팥죽을 싫어하는 나한테 팥죽을 전문으로 파는데가있다는것 자체만으로도 문화컬쳐역시 경험해보기 전에 함부로 판단하면 안된다고 느낌너무너무 맛있음ㅠㅠㅠ여지껏 삼청동에서 먹은 음식중 가장 맛있었다

# %%
# 정규 표현식 사용 예2
print(df['Review'][9])
print('*'*20)
print(apply_regular_expression(df['Review'][9]))
# Out:
# 진짜 손님 줄 관리를 못하네요 30분 넘게 기다렸는데 직원(?)이 이름 적었냐고 물어보지도 않고 그냥 지 맘대로 어디선가 부터 이름을 적기 시작하네여, 그런식으로 지 맘대로 하고는 열심히 기다린 저는 이름 안적었다고 저보다 늦게온 사람들 맨 뒤로 가라구 하고.. 하 참.... 어이가 없네여 죄송하단 사과 하나 없고 여기 방문하시는 분들은 줄이 어딘지 꼭 직...
# ********************
# 진짜 손님 줄 관리를 못하네요 분 넘게 기다렸는데 직원이 이름 적었냐고 물어보지도 않고 그냥 지 맘대로 어디선가 부터 이름을 적기 시작하네여 그런식으로 지 맘대로 하고는 열심히 기다린 저는 이름 안적었다고 저보다 늦게온 사람들 맨 뒤로 가라구 하고 하 참 어이가 없네여 죄송하단 사과 하나 없고 여기 방문하시는 분들은 줄이 어딘지 꼭 직

# %%
# 정규 표현식 사용 예3
print(df['Review'][len(df['Review'])-5])
print('*'*20)
print(apply_regular_expression(df['Review'][len(df['Review'])-5]))
# Out:
# 명란리조또가 정말 맛났다♥ 파스타보단 갠적으로 리조또종류들이 더맛있었다. 리조또 계란의 부드러움과 명란의 짭조름의 조화는 진짜 환상임!
# ********************
# 명란리조또가 정말 맛났다 파스타보단 갠적으로 리조또종류들이 더맛있었다 리조또 계란의 부드러움과 명란의 짭조름의 조화는 진짜 환상임

# %%
df["Re_Review"] = df["Review"].apply(lambda x : apply_regular_expression(x))
df
# Out:
#        Region  Rating          Category  \
# 0          수원       0                국수
# 1          제주       1             육류,고기
# 2         종로구       1          카페 / 디저트
# 3          중구       1                뷔페
# 4         강남구       0                분식
# ...       ...     ...               ...
# 141955    서초구       1             퓨전 일식
# 141956     세종       0             커피전문점
# 141957     진주       1            고기/구이류
# 141958    군산시       0            해산물 요리
# 141959    경주시       0  한정식 / 백반 / 정통 한식
#
#                                                    Review  \
# 0          원래 리뷰 잘 안남기는데 돈은 똑같이 처받고 여자남자 양 다르게 주는게 빡쳐서 남김
# 1                                  완전 맛있어 고기 또 구워주고 시네 최고
# 2       "이런데 누가 가?" 했는데 내가 감\n대박 맛있음\n팥죽 정말 싫어하는데 너무 맛...
# 3       영종도의 핫한 네스트호텔 내에 있는 플라츠 레스토랑.\n삼면이 통유리로 되어있어 파...
# 4                                       별한개도 아깝다. 줘도 안먹는다
# ...                                                   ...
# 141955  명란리조또가 정말 맛났다♥ 파스타보단 갠적으로 리조또종류들이 더맛있었다. 리조또 계...
# ...

# %%
df.drop("Review", axis=1, inplace=True)
df
# Out:
#        Region  Rating          Category  \
# 0          수원       0                국수
# 1          제주       1             육류,고기
# 2         종로구       1          카페 / 디저트
# 3          중구       1                뷔페
# 4         강남구       0                분식
# ...       ...     ...               ...
# 141955    서초구       1             퓨전 일식
# 141956     세종       0             커피전문점
# 141957     진주       1            고기/구이류
# 141958    군산시       0            해산물 요리
# 141959    경주시       0  한정식 / 백반 / 정통 한식
#
#                                                 Re_Review
# 0          원래 리뷰 잘 안남기는데 돈은 똑같이 처받고 여자남자 양 다르게 주는게 빡쳐서 남김
# 1                                  완전 맛있어 고기 또 구워주고 시네 최고
# 2       이런데 누가 가 했는데 내가 감대박 맛있음팥죽 정말 싫어하는데 너무 맛있어서 눈물이...
# 3       영종도의 핫한 네스트호텔 내에 있는 플라츠 레스토랑삼면이 통유리로 되어있어 파노라마...
# 4                                        별한개도 아깝다 줘도 안먹는다
# ...                                                   ...
# 141955  명란리조또가 정말 맛났다 파스타보단 갠적으로 리조또종류들이 더맛있었다 리조또 계란의...
# ...

# %% [markdown]
# # 3. Modeling - Logistic Regression

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
x_feature = df["Re_Review"].copy()
y_label = df["Rating"].copy()

# %% [markdown]
# ## 훈련 세트 및 테스트 세트 나누기

# %%
x_train, x_test, y_train, y_test = train_test_split(x_feature, y_label, test_size=0.2, random_state=42)

# %%
print(x_train[0:5])
print("*"*20)
print(y_train[0:5])
# Out:
# 39576                          직원분들 완전 친절하세요 가격대비 푸짐하고 맛있어요
# 38601     마라탕 정말 얼큰하고 맛있습니다 마라탕도 좋지만 이 집 꿔바로우찹쌀탕수육도 꼭 드셔보시길
# 67032     라이스류 다 맛있어요 간간이 음식대비 가격이 비싸다고 느껴지는 메뉴가 있긴 하지만 ...
# 109155                                             쫄쫄호떡괜찮네요
# 55857                                      부산사람은 안가는 비싼 고깃집
# Name: Re_Review, dtype: object
# ********************
# 39576     1
# 38601     1
# 67032     1
# 109155    1
# 55857     0
# Name: Rating, dtype: int64

# %%
print(x_test[0:5])
print("*"*20)
print(y_test[0:5])
# Out:
# 57827     감자탕에 감자는 없는 집 감자 따로 시켜야한다네 웃기 다시가면 사람이 아니어라 감자...
# 116287    원에 불고기 게장 홍어까지 다 맛볼 수 있다는 점은 좋은데 가게가 너무 시끄럽고 정...
# 49204     말이 필요없는 곳 그냥 최고 여자 두 명이서 인플래터 다 못먹을 정도로 양이 어마어...
# 140726    총평 김준현이 방송 안하고 먹기만 한 이유를 알 수 있는 집맛있는 녀석들에서 워낙 ...
# 5824      아 사진을 지웠구나모처럼의 거제여행중에 바닷가 짬뽕집이 맛있다고 얘기들어 폭풍검색을...
# Name: Re_Review, dtype: object
# ********************
# 57827     0
# 116287    0
# 49204     1
# 140726    1
# 5824      0
# Name: Rating, dtype: int64

# %% [markdown]
# ## BoW

# %%
from sklearn.feature_extraction.text import CountVectorizer

bow_vectorizer = CountVectorizer(analyzer='word', max_features=3000)

x_bow_train = bow_vectorizer.fit_transform(x_train)
y_train = np.array(y_train) 

x_bow_test = bow_vectorizer.transform(x_test)
y_test = np.array(y_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

lg_bow_model = LogisticRegression(class_weight='balanced')

hyper_parmas = {"max_iter": [1000, 2000, 3000]}

grid_lr_bow_model = GridSearchCV(lg_bow_model, param_grid=hyper_parmas, cv=5, refit=True, return_train_score=True)
grid_lr_bow_model.fit(x_bow_train, y_train)

print(f"모델의 최고 정확도 : {grid_lr_bow_model.best_score_}")

estimator = grid_lr_bow_model.best_estimator_
pred_y_bow = estimator.predict(x_bow_test)
# Out:
# 모델의 최고 정확도 : 0.8539729588201996

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test, pred_y_bow)

class_names=[0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('BoW - Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_y_bow, target_names=['neg', 'pos']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.84      0.88      0.86     14259
#          pos       0.87      0.83      0.85     14133
#
#     accuracy                           0.86     28392
#    macro avg       0.86      0.86      0.86     28392
# weighted avg       0.86      0.86      0.86     28392

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred_y_bow))
# Out:
# 0.8570019723865878

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(min_df = 0.0, analyzer='word', ngram_range=(1,3), max_features=3000)

x_tfidf_train = tfidf_vectorizer.fit_transform(x_train)
y_train = np.array(y_train)

x_tfidf_test = tfidf_vectorizer.transform(x_test)
y_test = np.array(y_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

lg_tfidf_model = LogisticRegression(class_weight='balanced')

hyper_parmas = {"max_iter": [1000, 2000, 3000]}

grid_lr_tfidf_model = GridSearchCV(lg_tfidf_model, param_grid=hyper_parmas, cv=5, refit=True, return_train_score=True)
grid_lr_tfidf_model.fit(x_tfidf_train, y_train)

print(f"모델의 최고 정확도 : {grid_lr_tfidf_model.best_score_}")

estimator = grid_lr_tfidf_model.best_estimator_
pred_y_tfidf = estimator.predict(x_tfidf_test)
# Out:
# 모델의 최고 정확도 : 0.8577240106505121

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test, pred_y_tfidf)

class_names=[0,1] 
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('TF-IDF - Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred_y_tfidf, target_names=['neg', 'pos']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.85      0.88      0.86     14259
#          pos       0.88      0.84      0.86     14133
#
#     accuracy                           0.86     28392
#    macro avg       0.86      0.86      0.86     28392
# weighted avg       0.86      0.86      0.86     28392

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred_y_tfidf))
# Out:
# 0.8614750633981403

# %% [markdown]
# ## Word2Vec

# %%
x_train_li = [sentence.split() for sentence in list(x_train)]
x_test_li = [sentence.split() for sentence in list(x_test)]

# %%
# !pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec(x_train_li, size=500, min_count=10, window=10)
model.save("./w2v_model")

# %%
def w2v_features(words, model, num_features):
  feature_vector = np.zeros((num_features), dtype=np.float32)

  count = 0
  index2word_set = set(model.wv.index2word)

  for word in words:
    if word in index2word_set:
      count += 1
      feature_vector = np.add(feature_vector, model[word])
      
  if count == 0:
    feature_vector = np.zeros((num_features), dtype=np.float32)
  else:
    feature_vector = np.divide(feature_vector, count)
  
  return feature_vector

# %%
def get_features(reviews, model, num_features):
  dataset = [w2v_features(sentence, model, num_features) for sentence in reviews]
  review_features_vecs = np.stack(dataset)

  return review_features_vecs

# %%
x_w2v_train = get_features(x_train_li, model, num_features=500)
y_train = np.array(y_train)

x_w2v_test = get_features(x_test_li, model, num_features=500)
y_test = np.array(y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

lg_w2v_model = LogisticRegression(class_weight='balanced')

hyper_parmas = {"max_iter": [1000, 2000, 3000]}

grid_lr_w2v_model = GridSearchCV(lg_w2v_model, param_grid=hyper_parmas, cv=5, refit=True, return_train_score=True)
grid_lr_w2v_model.fit(x_w2v_train, y_train)

print(f"모델의 최고 정확도 : {grid_lr_w2v_model.best_score_}")

estimator = grid_lr_w2v_model.best_estimator_
pred_y_w2v = estimator.predict(x_w2v_test)
# Out:
# 모델의 최고 정확도 : 0.8643367778911621

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test, pred_y_w2v)

class_names=[0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Word2Vec - Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred_y_w2v, target_names=['neg', 'pos']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.88      0.85      0.87     14259
#          pos       0.86      0.88      0.87     14133
#
#     accuracy                           0.87     28392
#    macro avg       0.87      0.87      0.87     28392
# weighted avg       0.87      0.87      0.87     28392

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred_y_w2v))
# Out:
# 0.8670047900817132

# %% [markdown]
# # 4. Modeling - DecisionTree

# %% [markdown]
# ## BoW

# %%
from sklearn.feature_extraction.text import CountVectorizer

bow_vectorizer = CountVectorizer(analyzer='word', max_features=3000)

x_bow_train = bow_vectorizer.fit_transform(x_train)
y_train = np.array(y_train) 

x_bow_test = bow_vectorizer.transform(x_test)
y_test = np.array(y_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

dt_bow_model = DecisionTreeClassifier(class_weight='balanced')

hyper_parmas = {"min_impurity_decrease": [0.0001, 0.0002, 0.0003, 0.0004, 0.0005]}

grid_lr_bow_model = GridSearchCV(dt_bow_model, param_grid=hyper_parmas, cv=5, refit=True, return_train_score=True)
grid_lr_bow_model.fit(x_bow_train, y_train)

print(f"모델의 최고 정확도 : {grid_lr_bow_model.best_score_}")

estimator = grid_lr_bow_model.best_estimator_
pred_y_bow = estimator.predict(x_bow_test)
# Out:
# 모델의 최고 정확도 : 0.7656470313546218

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test, pred_y_bow)

class_names=[0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('BoW - Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_y_bow, target_names=['neg', 'pos']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.73      0.84      0.78     14259
#          pos       0.81      0.70      0.75     14133
#
#     accuracy                           0.77     28392
#    macro avg       0.77      0.77      0.76     28392
# weighted avg       0.77      0.77      0.76     28392

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred_y_bow))
# Out:
# 0.7661665257819104

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(min_df = 0.0, analyzer='word', ngram_range=(1,3), max_features=3000)

x_tfidf_train = tfidf_vectorizer.fit_transform(x_train)
y_train = np.array(y_train)

x_tfidf_test = tfidf_vectorizer.transform(x_test)
y_test = np.array(y_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

dt_tfidf_model = DecisionTreeClassifier(class_weight='balanced')

hyper_parmas = {"min_impurity_decrease": [0.0001, 0.0002, 0.0003, 0.0004, 0.0005]}

grid_lr_tfidf_model = GridSearchCV(dt_tfidf_model, param_grid=hyper_parmas, cv=5, refit=True, return_train_score=True)
grid_lr_tfidf_model.fit(x_tfidf_train, y_train)

print(f"모델의 최고 정확도 : {grid_lr_tfidf_model.best_score_}")

estimator = grid_lr_tfidf_model.best_estimator_
pred_y_tfidf = estimator.predict(x_tfidf_test)
# Out:
# 모델의 최고 정확도 : 0.768843350309739

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test, pred_y_tfidf)

class_names=[0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('TF-IDF - Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred_y_tfidf, target_names=['neg', 'pos']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.74      0.84      0.79     14259
#          pos       0.81      0.70      0.75     14133
#
#     accuracy                           0.77     28392
#    macro avg       0.77      0.77      0.77     28392
# weighted avg       0.77      0.77      0.77     28392

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred_y_tfidf))
# Out:
# 0.7694773175542406

# %% [markdown]
# ## Word2Vec

# %%
x_train_li = [sentence.split() for sentence in list(x_train)]
x_test_li = [sentence.split() for sentence in list(x_test)]

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec(x_train_li, size=500, min_count=10, window=10)
model.save("./w2v_model")

# %%
x_w2v_train = get_features(x_train_li, model, num_features=500)
y_train = np.array(y_train)

x_w2v_test = get_features(x_test_li, model, num_features=500)
y_test = np.array(y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

dt_w2v_model = DecisionTreeClassifier(class_weight='balanced')

hyper_parmas = {"min_impurity_decrease": [0.0001, 0.0002, 0.0003, 0.0004, 0.0005]}

grid_lr_w2v_model = GridSearchCV(dt_w2v_model, param_grid=hyper_parmas, cv=5, refit=True, return_train_score=True)
grid_lr_w2v_model.fit(x_w2v_train, y_train)

print(f"모델의 최고 정확도 : {grid_lr_w2v_model.best_score_}")

estimator = grid_lr_w2v_model.best_estimator_
pred_y_w2v = estimator.predict(x_w2v_test)
# Out:
# 모델의 최고 정확도 : 0.8432921476518723

# %%
from sklearn.metrics import confusion_matrix

cnf_matrix = confusion_matrix(y_test, pred_y_w2v)

class_names=[0,1]
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Word2Vec - Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred_y_w2v, target_names=['neg', 'pos']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.85      0.83      0.84     14259
#          pos       0.83      0.85      0.84     14133
#
#     accuracy                           0.84     28392
#    macro avg       0.84      0.84      0.84     28392
# weighted avg       0.84      0.84      0.84     28392

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred_y_w2v))
# Out:
# 0.8436883629191322

# %% [markdown]
# # 5. 감성분석

# %% [markdown]
# ## KoNLPy Setting

# %%
# !apt-get update
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev

# !pip3 install JPype1-py3
# !pip3 install konlpy
# !JAVA_HOME="C:\Program Files\Java\jdk-19"
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,040 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,554 kB]
# ...

# %%
from konlpy.tag import Kkma, Komoran, Hannanum, Okt
kkma = Kkma()
komoran = Komoran()
hannanum = Hannanum()
okt = Okt()

# %%
df
# Out:
#        Region  Rating          Category  \
# 0          수원       0                국수
# 1          제주       1             육류,고기
# 2         종로구       1          카페 / 디저트
# 3          중구       1                뷔페
# 4         강남구       0                분식
# ...       ...     ...               ...
# 141955    서초구       1             퓨전 일식
# 141956     세종       0             커피전문점
# 141957     진주       1            고기/구이류
# 141958    군산시       0            해산물 요리
# 141959    경주시       0  한정식 / 백반 / 정통 한식
#
#                                                 Re_Review
# 0          원래 리뷰 잘 안남기는데 돈은 똑같이 처받고 여자남자 양 다르게 주는게 빡쳐서 남김
# 1                                  완전 맛있어 고기 또 구워주고 시네 최고
# 2       이런데 누가 가 했는데 내가 감대박 맛있음팥죽 정말 싫어하는데 너무 맛있어서 눈물이...
# 3       영종도의 핫한 네스트호텔 내에 있는 플라츠 레스토랑삼면이 통유리로 되어있어 파노라마...
# 4                                        별한개도 아깝다 줘도 안먹는다
# ...                                                   ...
# 141955  명란리조또가 정말 맛났다 파스타보단 갠적으로 리조또종류들이 더맛있었다 리조또 계란의...
# ...

# %% [markdown]
# ## 형태소 분석

# %%
def get_pos (x) :
    tagger = Okt()
    pos = tagger.pos(x)
    
    result = []
    
    for a1 in pos :
        result.append(f'{a1[0]}/{a1[1]}')
    
    return result

# %%
get_pos(df['Re_Review'][0])
# Out:
# ['원래/Noun',
#  '리뷰/Noun',
#  '잘/Verb',
#  '안/VerbPrefix',
#  '남기는데/Verb',
#  '돈/Noun',
#  '은/Josa',
#  '똑같이/Adverb',
#  '처/Noun',
#  '받고/Verb',
#  '여자/Noun',
#  '남자/Noun',
#  '양/Noun',
#  '다르게/Adjective',
#  '주는게/Verb',
#  '빡쳐서/Adjective',
#  '남김/Verb']

# %% [markdown]
# ## 형태소 벡터 생성

# %%
from sklearn.feature_extraction.text import CountVectorizer

df_vector = df.sample(n=10000, random_state=45)

index_vectorizer = CountVectorizer(tokenizer=lambda x : get_pos(x))
X = index_vectorizer.fit_transform(df_vector["Re_Review"].tolist())

# %%
index_vectorizer.vocabulary_
# Out:
# {'맛/Noun': 12185,
#  '은/Josa': 26746,
#  '중상/Noun': 30467,
#  '서비스/Noun': 19262,
#  '는/Josa': 7022,
#  '최하/Noun': 32605,
#  '직원/Noun': 30918,
#  '들/Suffix': 9703,
#  '장사/Noun': 28708,
#  '를/Josa': 11186,
#  '하겠다는/Verb': 35355,
#  '건지/Verb': 1792,
#  '말겠다는/Verb': 12042,
#  '짜증/Noun': 31263,
#  '만/Josa': 11593,
#  '엄청/Adverb': 24271,
#  '내고/Verb': 5722,
#  '그릇/Noun': 3440,
#  '놓는것도/Verb': 6566,
#  '툭툭/Noun': 34095,
#  '물어봐도/Verb': 14390,
#  '대충/Noun': 8198,
#  '대답/Noun': 8094,
#  '기분/Noun': 3863,
#  '나빠서/Adjective': 4973,
#  '뭔/Modifier': 14502,
#  '인지도/Noun': 27575,
#  '모르겠다/Verb': 13720,
#  '도/Josa': 8546,
#  '평범/Noun': 34831,
#  '양은/Noun': 23707,
#  '도둑질/Noun': 8565,
#  '고객/Noun': 2215,
#  '의/Josa': 26826,
#  '안전/Noun': 22839,
#  '나/Noun': 4805,
#  '몰/Verb': 13891,
#  '라라/Noun': 10876,
#  '하/Suffix': 35336,
#  '누/Noun': 6628,
#  '돈독/Noun': 8700,
#  '이/Josa': 26869,
#  '오른/Noun': 25287,
#  '양심/Noun': 23701,
#  '불량/Noun': 17117,
#  '치입니다/Verb': 32890,
#  '별관/Noun': 16049,
# ...

# %%
df_vector
# Out:
#        Region  Rating     Category  \
# 82385      속초       0           국수
# 59298    영등포구       0        족발,보쌈
# 63243     종로구       1  탕 / 찌개 / 전골
# 22416     동작구       0        해산물뷔페
# 77862    서귀포시       0    국수 / 면 요리
# ...       ...     ...          ...
# 85714     인덕원       1        물회 횟집
# 111639     중구       1  탕 / 찌개 / 전골
# 125787     춘천       0          닭요리
# 36896      중구       1          프렌치
# 128438     김포       1        해물,생선
#
#                                                 Re_Review
# 82385   맛은 중상 서비스는 최하 직원들은 장사를 하겠다는건지 말겠다는건지 짜증만 엄청내고 ...
# 59298   맛도 평범 양은 도둑질 고객의 안전은 나몰라라하누 돈독이 오른 양심불량 장사치입니다...
# 63243   만두전골의 경우 평안도 음식 특유의 슴슴하지만 여운이 남는 맛이 인상적이다 양지로 ...
# 22416                                   다 좋은데 갑질만 없으면 좋겠군
# 77862   직원들 서비스 마인드 꽝이었음들어가서 주문 받아달라고 하니 멀뚱멀뚱 서 있다가 아무...
# ...                                                   ...
# 85714   거제에 가면서 짠내투어에 나왔던 물회집에 가보자고 해서 간 식당인데 생각보다 맛도 ...
# 111639  명동 골목에 숨어 있는 전통 맛집굉장히 훌륭한 맛입니다 설렁탕 아주 좋아하는 편인데...
# ...

# %%
# 첫번째 행 리뷰
print(df_vector["Re_Review"].iloc[0])
# 첫번째 행 긍정/부정
print(df_vector["Rating"].iloc[0])
# 첫번째 행의 index_vectorizer의 (형태소, 시리얼넘버) 
print(X[0])
# Out:
# 맛은 중상 서비스는 최하 직원들은 장사를 하겠다는건지 말겠다는건지 짜증만 엄청내고 그릇놓는것도 툭툭 물어봐도 대충대답 기분나빠서 뭔맛인지도 모르겠다
# 0
#   (0, 12185)	2
#   (0, 26746)	2
#   (0, 30467)	1
#   (0, 19262)	1
#   (0, 7022)	1
#   (0, 32605)	1
#   (0, 30918)	1
#   (0, 9703)	1
#   (0, 28708)	1
#   (0, 11186)	1
#   (0, 35355)	1
#   (0, 1792)	2
#   (0, 12042)	1
#   (0, 31263)	1
#   (0, 11593)	1
#   (0, 24271)	1
#   (0, 5722)	1
#   (0, 3440)	1
#   (0, 6566)	1
#   (0, 34095)	1
#   (0, 14390)	1
#   (0, 8198)	1
#   (0, 8094)	1
#   (0, 3863)	1
#   (0, 4973)	1
#   (0, 14502)	1
#   (0, 27575)	1
#   (0, 13720)	1

# %% [markdown]
# ## TF-IDF 벡터로 생성

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_vectorizer = TfidfTransformer()
X = tfidf_vectorizer.fit_transform(X)
print(X[0])
# Out:
#   (0, 35355)	0.26370731651796636
#   (0, 34095)	0.21276136158420317
#   (0, 32605)	0.25703872931685884
#   (0, 31263)	0.18483977216092462
#   (0, 30918)	0.10872540371313204
#   (0, 30467)	0.25703872931685884
#   (0, 28708)	0.14724918999034065
#   (0, 27575)	0.2284835174127094
#   (0, 26746)	0.12413242430552009
#   (0, 24271)	0.12350760086799922
#   (0, 19262)	0.1098323725176775
#   (0, 14502)	0.17610935087563293
#   (0, 14390)	0.2334758854391054
#   (0, 13720)	0.18038588250179743
#   (0, 12185)	0.1191691022664064
#   (0, 12042)	0.26370731651796636
#   (0, 11593)	0.09712817618838426
#   (0, 11186)	0.08140086559646037
#   (0, 9703)	0.08158570292971282
#   (0, 8198)	0.19204683772930092
#   (0, 8094)	0.1907184083249973
#   (0, 7022)	0.06813345896067585
#   (0, 6566)	0.2844218403728686
#   (0, 5722)	0.17133231387439868
#   (0, 4973)	0.22227826880816182
#   (0, 3863)	0.12541804530479203
#   (0, 3440)	0.15327991167776006
#   (0, 1792)	0.29857872123038565

# %% [markdown]
# ## 모델링

# %%
y = df_vector["Rating"]

# %% [markdown]
# ### 1) KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

params = {
	"n_neighbors" : list(range(1, 11))
}

model1 = KNeighborsClassifier()

kfold = KFold(n_splits=10, shuffle=True, random_state = 1)
grid_clf1 = GridSearchCV(model1, param_grid = params, scoring="accuracy", cv=kfold)
grid_clf1.fit(X, y)

print(f"최적의 하이퍼 파라미터 : {grid_clf1.best_params_}")
print(f"최적의 모델 정확도 : {grid_clf1.best_score_}")
# Out:
# 최적의 하이퍼 파라미터 : {'n_neighbors': 3}
# 최적의 모델 정확도 : 0.5130999999999999

# %% [markdown]
# ### 2) LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

params = {
    'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    'C' : [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]
}

model2 = LogisticRegression()

kfold = KFold(n_splits=10, shuffle=True, random_state = 1)
grid_clf2 = GridSearchCV(model2, param_grid=params, scoring='accuracy', cv=kfold)
grid_clf2.fit(X, y)

print(f'최적의 하이퍼 파라미터 : {grid_clf2.best_params_}')
print(f'최적의 모델 정확도 : {grid_clf2.best_score_}')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:1484: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio parameters"
# ...

# %% [markdown]
# ### 3) RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate

model3 = RandomForestClassifier(n_jobs=-1, random_state=45)

scores_rf = cross_validate(model3, X, y, return_train_score=True, n_jobs=-1)

print(np.mean(scores_rf['train_score']), np.mean(scores_rf['test_score']))
# Out:
# 0.9982 0.8581

# %% [markdown]
# ### 4) XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate

model4 = XGBClassifier(tree_method = 'hist', random_state=45)

scores_xg = cross_validate(model4, X, y, return_train_score=True, n_jobs=-1)

print(np.mean(scores_xg['train_score']), np.mean(scores_xg['test_score']))
# Out:
# /usr/local/lib/python3.7/dist-packages/joblib/externals/loky/process_executor.py:703: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# 0.8273249999999999 0.796

# %% [markdown]
# https://moojuksublime.tistory.com/14

# %% [markdown]
# ## 중요 keyword 파악

# %%
# Logistic Regression으로 모델링
model = grid_clf2.best_estimator_

arr1 = (model.coef_[0])
display(arr1)
len(arr1)
# Out:
# array([-0.88743015,  0.4658345 , -0.1514237 , ..., -0.04329253,
#         0.51680276, -0.14192458])
# 37749

# %%
arr2 = list(enumerate(arr1)) # 상관계수에 번호 붙인 후 튜플 형태로
arr2
# Out:
# [(0, -0.8874301515809822),
#  (1, 0.4658344981517415),
#  (2, -0.1514237036855251),
#  (3, -0.0006213575147526081),
#  (4, 0.02941628289941366),
#  (5, -0.17312015649020565),
#  (6, -0.049228217903772284),
#  (7, -0.0906081038247655),
#  (8, 0.10541059644232359),
#  (9, -0.04073744337784907),
#  (10, -0.35242870475314353),
#  (11, -0.7372721156870893),
#  (12, 0.012147811402044966),
#  (13, 0.3093710010918115),
#  (14, 0.3935501303998799),
#  (15, 0.3580787353634173),
#  (16, 0.24960079173462757),
#  (17, 0.6295402837276665),
#  (18, 0.18632691578607014),
#  (19, 0.3214412157564224),
#  (20, -0.235440665371297),
#  (21, -0.44446653637793226),
#  (22, 0.44554476304344964),
#  (23, -0.010217974537706604),
#  (24, -0.8217406241053861),
#  (25, 1.6229288929291954),
#  (26, 0.8583963556085404),
#  (27, -0.9454511527973447),
#  (28, 0.6776601895717114),
#  (29, -0.07571185184276255),
#  (30, -0.05464772253994236),
#  (31, -1.5644128784549094),
#  (32, -0.037409070977256854),
# ...

# %%
# 위치 변경 후 내림차순 정렬
arr3 = []

for idx, value in arr2 : 
	arr3.append((value, idx))
    
coef_pos_sort = sorted(arr3, reverse=True)
coef_pos_sort
# Out:
# [(11.224248398656394, 12469),
#  (9.26575843521992, 12523),
#  (8.697793106620642, 12347),
#  (8.647680859649798, 12568),
#  (7.324236017576349, 32575),
#  (7.295082856866836, 29671),
#  (7.013082925066941, 12397),
#  (6.983970807664727, 29987),
#  (6.727097246065537, 4452),
#  (6.477505132913501, 29799),
#  (6.288321913699799, 29836),
#  (6.2832831629943, 93),
#  (5.8697068848524925, 32653),
#  (5.805240281705169, 12502),
#  (5.3698157086525775, 30027),
#  (5.3494304700836315, 36180),
#  (5.336415496031969, 10645),
#  (5.234824291414284, 29779),
#  (5.194540209168896, 12373),
#  (5.1480448045953455, 29983),
#  (5.057498004175759, 12338),
#  (5.055926179417559, 12518),
#  (5.010499666603285, 12454),
#  (4.974477042504319, 7425),
#  (4.9723372858990365, 12464),
#  (4.904398735568944, 29824),
#  (4.811383727303029, 34996),
#  (4.809897836620233, 28069),
#  (4.7386074754674175, 94),
#  (4.723298098442487, 19933),
#  (4.722141502961088, 3104),
#  (4.716639616519625, 36068),
# ...

# %%
text_data_dict = {}

for key in index_vectorizer.vocabulary_ :
    value = index_vectorizer.vocabulary_[key]
    text_data_dict[value] = key
    
text_data_dict
# Out:
# {12185: '맛/Noun',
#  26746: '은/Josa',
#  30467: '중상/Noun',
#  19262: '서비스/Noun',
#  7022: '는/Josa',
#  32605: '최하/Noun',
#  30918: '직원/Noun',
#  9703: '들/Suffix',
#  28708: '장사/Noun',
#  11186: '를/Josa',
#  35355: '하겠다는/Verb',
#  1792: '건지/Verb',
#  12042: '말겠다는/Verb',
#  31263: '짜증/Noun',
#  11593: '만/Josa',
#  24271: '엄청/Adverb',
#  5722: '내고/Verb',
#  3440: '그릇/Noun',
#  6566: '놓는것도/Verb',
#  34095: '툭툭/Noun',
#  14390: '물어봐도/Verb',
#  8198: '대충/Noun',
#  8094: '대답/Noun',
#  3863: '기분/Noun',
#  4973: '나빠서/Adjective',
#  14502: '뭔/Modifier',
#  27575: '인지도/Noun',
#  13720: '모르겠다/Verb',
#  8546: '도/Josa',
#  34831: '평범/Noun',
#  23707: '양은/Noun',
#  8565: '도둑질/Noun',
#  2215: '고객/Noun',
#  26826: '의/Josa',
#  22839: '안전/Noun',
#  4805: '나/Noun',
#  13891: '몰/Verb',
#  10876: '라라/Noun',
#  35336: '하/Suffix',
#  6628: '누/Noun',
#  8700: '돈독/Noun',
#  26869: '이/Josa',
#  25287: '오른/Noun',
#  23701: '양심/Noun',
#  17117: '불량/Noun',
#  32890: '치입니다/Verb',
#  16049: '별관/Noun',
# ...

# %%
# 긍정 keyword
top20 = coef_pos_sort[:20]
# 부정 keyword
bottom20 = coef_pos_sort[-20:]

# %%
for value, idx in top20 : 
	print(text_data_dict[idx])
# Out:
# 맛있어요/Adjective
# 맛있었어요/Adjective
# 맛있고/Adjective
# 맛있음/Adjective
# 최고/Noun
# 존맛/Noun
# 맛있다/Adjective
# 좋았어요/Adjective
# 꼭/Noun
# 좋다/Adjective
# 좋아요/Adjective
# ㅎㅎ/KoreanParticle
# 추천/Noun
# 맛있었다/Adjective
# 좋은/Adjective
# 항상/Noun
# 또/Noun
# 좋고/Adjective
# 맛있네요/Adjective
# 좋았습니다/Adjective

# %%
for value, idx in bottom20 : 
	print(text_data_dict[idx])
# Out:
# 아니고/Adjective
# 모르겠어요/Verb
# 없어요/Adjective
# 없고/Adjective
# 없음/Adjective
# 장사/Noun
# 맛없음/Adjective
# 그나마/Adverb
# 손님/Noun
# 그닥/Noun
# 건지/Verb
# 왜/Noun
# 돈/Noun
# 차라리/Noun
# 안/VerbPrefix
# 최악/Noun
# 불친절/Noun
# 그냥/Noun
# 실망/Noun
# 별로/Noun

# %% [markdown]
# # 워드클라우드

# %%
from wordcloud import WordCloud # 워드클라우드를 생성을 위한 기본 모듈
from collections import Counter
from PIL import Image # 워드클라우드를 원하는 형태로 그리기 위해 그림을 불러오는 패키지

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum-eco.
# (Reading database ... 124539 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
pos['Review']
# Out:
# 0         숙성 돼지고기 전문점입니다. 건물 모양 때문에 매장 모양도 좀 특이하지만 쾌적한 편...
# 1         고기가 정말 맛있었어요! 육즙이 가득있어서 너무 좋았아요\n일하시는분들 너무 친절하...
# 2         잡내없고 깔끔, 담백한 맛의 순대국이 순대국을 안 좋아하는 사람들에게도 술술 넘어갈...
# 3         고기 양이 푸짐해서 특 순대국밥을 시킨 기분이 듭니다~~ 맛도 좋습니다\n다만 양념...
# 4         순대국 자체는 제가 먹어본 순대국밥집 중에서 Top5 안에는 들어요.\n\n그러나 ...
#                                 ...
# 642392    가격대비 괜찮긴한데 가격을 자꾸 올리고 샐러드바 메뉴는 줄어드는 경향이 있어서 살짝...
# 642401    리뷰에직원이 친절하지않다더니 정말이네요 선불이라 만원짜리내고 기다리고있는데 거지동냥...
# 642405    송탄 미군부대 근처에 위치한 곳 원래 로컬맛집으로 되게 유명했는데 삼대천왕에 나온 ...
# 642406    집에서 40키로 정도 떨어져 있는 곳인데도 몇달에 한번은 이거 먹으러 일부러 갑니다...
# 642410    우리팀 단골집, 술먹고 다음 날 가면 푸짐하게 배불리 해장 할 수 있는곳, 주말도 ...
# Name: Review, Length: 388567, dtype: object

# %%
len(str(pos['Review'][:60]))
# Out:
# 3387

# %%
len(str(pos['Review'][:61]))
# 60개 이상을 slicing하면 개수가 줄어들음..
# Out:
# 655

# %%
len(str(pos['Review'][61:120]))
# Out:
# 3390

# %%
len(str(pos['Review'][121:180]))
# Out:
# 3390

# %%
len(str(pos['Review'][:60]) + str(pos['Review'][61:120]) + str(pos['Review'][121:180]) + str(pos['Review'][181:240]) + str(pos['Review'][241:300]) + str(pos['Review'][361:420]) + str(pos['Review'][421:480]) + str(pos['Review'][481:540]) + str(pos['Review'][541:600]))
# Out:
# 30507

# %%
review_pos = str(pos['Review'][:60]) + str(pos['Review'][61:120]) + str(pos['Review'][121:180]) + str(pos['Review'][181:240]) + str(pos['Review'][241:300]) + str(pos['Review'][301:360]) + str(pos['Review'][361:420]) + str(pos['Review'][421:480]) + str(pos['Review'][481:540]) + str(pos['Review'][541:600])

okt = Okt()
nouns_pos = okt.nouns(review_pos)

words_pos = [n for n in nouns_pos if len(n) > 1] # 단어의 길이가 1개인 것은 제외

count_pos = Counter(words_pos)

# %%
len(count_pos)
# Out:
# 1088

# %%
wc = WordCloud(font_path='/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(count_pos)
plt.figure()
plt.imshow(gen)

# %%
len(neg['Review'])
# Out:
# 70980

# %%
len(str(neg['Review'][:60])+str(neg['Review'][61:120])+str(neg['Review'][121:180])+str(neg['Review'][181:240])+str(neg['Review'][241:300])+str(neg['Review'][301:360]) + str(neg['Review'][361:420]) + str(neg['Review'][421:480]) + str(neg['Review'][481:540]) + str(neg['Review'][541:600]))
# Out:
# 34548

# %%
review_neg = str(neg['Review'][:60]) + str(neg['Review'][61:120]) + str(neg['Review'][121:180]) + str(neg['Review'][181:240]) + str(neg['Review'][241:300]) + str(neg['Review'][301:360]) + str(neg['Review'][361:420]) + str(neg['Review'][421:480]) + str(neg['Review'][481:540]) + str(neg['Review'][541:600])

nouns_neg = okt.nouns(review_neg)

words_neg = [n for n in nouns_neg if len(n) > 1] # 단어의 길이가 1개인 것 제외

count_neg = Counter(words_neg)

# %%
gen = wc.generate_from_frequencies(count_neg)
plt.figure()
plt.imshow(gen)
